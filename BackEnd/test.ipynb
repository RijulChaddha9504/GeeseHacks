# %%
import pyaudio
import wave

#Define audio parameters
FORMAT = pyaudio.paInt16  # Audio format
CHANNELS = 1  # Number of channels (mono)
RATE = 44100  # Sample rate
CHUNK = 1024  # Block size

#Initialize PyAudio object
audio = pyaudio.PyAudio()

#Open microphone stream
stream = audio.open(format=FORMAT,
                    channels=CHANNELS,
                    rate=RATE,
                    input=True,
                    frames_per_buffer=CHUNK)

print("Recording...")

#Create an empty byte array to store the recorded audio
frames = []

#Record audio for a specific duration (e.g., 5 seconds)
try:
    for i in range(0, int(RATE / CHUNK * 5)):  # Record for 5 seconds
        data = stream.read(CHUNK)
        frames.append(data)
except KeyboardInterrupt:
    print("Recording stopped by user")

print("Finished recording.")

#Stop and close the audio stream
stream.stop_stream()
stream.close()
audio.terminate()

#Save the recorded audio to a WAV file
waveFile = wave.open("enth_audio.wav", 'wb')
waveFile.setnchannels(CHANNELS)
waveFile.setsampwidth(audio.get_sample_size(FORMAT))
waveFile.setframerate(RATE)
waveFile.writeframes(b''.join(frames))
waveFile.close()

print("Audio saved to recorded_audio.wav")
# Out:
# Running cells with 'Python 3.11.7' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/msys64/ucrt64/bin/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
import google.generativeai as genai
#from google import genai
import json
import vertexai
from vertexai.preview.vision_models import ImageGenerationModel

import time

class chatBot:
        def interview_mode(fil):
                genai.configure(api_key="REPLACE WITH YOUR API KEY")

                myfile = genai.upload_file(fil)#"decoded_video.mp4")#"petal_20250118_012647.mp4")
                print(f"{myfile=}")

#Videos need to be processed before you can use them.
                while myfile.state.name == "PROCESSING":
                        print("processing video...")
                        time.sleep(5)
                myfile = genai.get_file(myfile.name)

#prompt = "Analyze the emotions, facial expressions, and body language displayed in this clip. \
 #           Describe ways the person can improve their non verbal communication."

                prompt = "You are an interview chatbot. Analyze the tone to ensure its formal, emotions, and how the user is showing interest in the company. After grading the user's response, provide a followup question. Provide short feedback for improvement"
                prompt2 = "As an interview chatbot, Analyze the tone to ensure its formal, emotions, and how the user is showing interest in the company. Give them an integer grade from 0-100 regarding how well the user followed these categories. ONLY WRITE ONE INTEGER NUMBER"

                model = genai.GenerativeModel("gemini-1.5-flash")
                result = model.generate_content([myfile, prompt])
                gradeResult = model.generate_content([myfile, prompt2])           
                print("")
                print(f"{result.text=}")
                print("")
                print(f"{gradeResult.text}")

                with open("interview.txt", "w") as f:
                        f.write(result.text)
                print("")

                interview_data = {
                        "response_analysis": result.text.strip(),
                        "grade": int(gradeResult.text.strip())  # Ensure the grade is an integer
                }
    
    # Print the results
                print(f"{result.text=}")
                print(f"{gradeResult.text=}")

    # Save the results to a JSON file
                with open("interview_results.json", "w") as json_file:
                        json.dump(interview_data, json_file, indent=4)
    
                print("Interview results saved as interview_results.json")
    
        def conversational_mode(fil):
                genai.configure(api_key="REPLACE WITH YOUR API KEY")

                myfile = genai.upload_file(fil)#"decoded_video.mp4")#"petal_20250118_012647.mp4")
                print(f"{myfile=}")

#Videos need to be processed before you can use them.
                while myfile.state.name == "PROCESSING":
                        print("processing video...")
                        time.sleep(5)
                myfile = genai.get_file(myfile.name)

#prompt = "Analyze the emotions, facial expressions, and body language displayed in this clip. \
 #           Describe ways the person can improve their non verbal communication."

                prompt = "Analyze the tone, emotions, and how engaging the user's voice is. Engage in a conversation with the user by providing them with a question. Provide short feedback for improvement"
                prompt2 = "As an conversational chatbot, analyze the tone to ensure the user is interested, emotions, and how the user is showing interest in the conversation. Give them an integer grade from 0-100 regarding how well the user followed these categories. ONLY WRITE ONE INTEGER NUMBER"

                model = genai.GenerativeModel("gemini-1.5-flash")
                result = model.generate_content([myfile, prompt])
                gradeResult = model.generate_content([myfile, prompt2])           
                print("")
                print(f"{result.text=}")
                print("")
                print(f"{gradeResult.text}")

                with open("interview.txt", "w") as f:
                        f.write(result.text)
                print("")

                conversation_data = {
                        "response_analysis": result.text.strip(),
                        "grade": int(gradeResult.text.strip())  # Ensure the grade is an integer
                }
    
    # Print the results
                print(f"{result.text=}")
                print(f"{gradeResult.text=}")

    # Save the results to a JSON file
                with open("conversation_results.json", "w") as json_file:
                        json.dump(conversation_data, json_file, indent=4)
    
                print("Interview results saved as interview_results.json")

chatBot.conversational_mode("enth_audio.wav")
chatBot.interview_mode("enth_audio.wav")
# Out:
# myfile=genai.File({
#     'name': 'files/nitxrepbqeqs',
#     'display_name': 'enth_audio.wav',
#     'mime_type': 'audio/wav',
#     'sha256_hash': 'MDRhN2RjYmZmZTQwZGEwZTY3Y2ZmMjFmZjY4MWNjNzk3MTFlMDczZTBlNGI3ZjEwOWEwYjE2NzYzOTI5OGJjNg==',
#     'size_bytes': '409644',
#     'state': 'ACTIVE',
#     'uri': 'https://generativelanguage.googleapis.com/v1beta/files/nitxrepbqeqs',
#     'create_time': '2025-01-25T22:42:07.370704Z',
#     'expiration_time': '2025-01-27T22:42:07.367989578Z',
#     'update_time': '2025-01-25T22:42:07.370704Z'})
#
# result.text='The tone is polite and respectful, conveying genuine interest. The emotion is one of eager anticipation.  The voice is quite engaging, thanks to the clear pronunciation and the respectful "Sir."  However, the single "P" sound effect is jarring and detracts from the otherwise polished delivery. It\'s unclear what purpose it serves.\n\nTo improve, remove the "P" sound.  A more natural and engaging delivery would benefit from slightly more variation in intonation and pace.  It sounds a bit monotone currently.\n\n\nMy question to you is:  "What specifically interests you about what I have to say?  Knowing that will help me tailor my response."\n'
#
# 95
#
#
# result.text='The tone is polite and respectful, conveying genuine interest. The emotion is one of eager anticipation.  The voice is quite engaging, thanks to the clear pronunciation and the respectful "Sir."  However, the single "P" sound effect is jarring and detracts from the otherwise polished delivery. It\'s unclear what purpose it serves.\n\nTo improve, remove the "P" sound.  A more natural and engaging delivery would benefit from slightly more variation in intonation and pace.  It sounds a bit monotone currently.\n\n\nMy question to you is:  "What specifically interests you about what I have to say?  Knowing that will help me tailor my response."\n'
# gradeResult.text='95\n'
# Interview results saved as interview_results.json
# myfile=genai.File({
#     'name': 'files/nktryg8uea0h',
#     'display_name': 'enth_audio.wav',
#     'mime_type': 'audio/wav',
#     'sha256_hash': 'MDRhN2RjYmZmZTQwZGEwZTY3Y2ZmMjFmZjY4MWNjNzk3MTFlMDczZTBlNGI3ZjEwOWEwYjE2NzYzOTI5OGJjNg==',
#     'size_bytes': '409644',
#     'state': 'ACTIVE',
#     'uri': 'https://generativelanguage.googleapis.com/v1beta/files/nktryg8uea0h',
#     'create_time': '2025-01-25T22:42:11.114766Z',
#     'expiration_time': '2025-01-27T22:42:11.076295114Z',
#     'update_time': '2025-01-25T22:42:11.114766Z'})
#
# result.text='**Tone Analysis:**\n\nThe tone is highly formal and respectful.  The use of "sir," "very interested," and the polite phrasing ("what you have to say") clearly indicates a formal and deferential approach. There\'s no detectable emotion beyond polite interest.\n\n**Interest in the Company:**\n\nThe statement shows a high level of interest. The phrase "very interested in what you have to say" implies a strong desire to learn more about the company, its work, and the interviewee\'s perspective within it.  However, it\'s indirect.  It would be stronger if the interest were linked directly to something specific about the company or role.\n\n**Grade:**\n\nB+  (Good, but could be improved)\n\n\n**Follow-up Question:**\n\n"That\'s excellent.  To help me understand your interest better, could you tell me what specifically about [Company Name/the role/this interview opportunity] has piqued your interest?"\n\n\n**Feedback for Improvement:**\n\nWhile politeness is key, the response lacks specificity.  To make it even stronger, the user should mention something specific that generated their interest. For example:\n\n* "Hello sir, I\'m very interested in what you have to say, particularly regarding [Company Name]\'s recent work on [Specific Project or Initiative]."\n* "Hello sir, I\'m very interested in hearing your perspective on [Aspect of the role/company culture] as described in the job description."\n\nBy adding a specific detail, the candidate demonstrates more focused interest and shows they\'ve done their research.  This makes a stronger impression.\n'
#
# 95
#
#
# result.text='**Tone Analysis:**\n\nThe tone is highly formal and respectful.  The use of "sir," "very interested," and the polite phrasing ("what you have to say") clearly indicates a formal and deferential approach. There\'s no detectable emotion beyond polite interest.\n\n**Interest in the Company:**\n\nThe statement shows a high level of interest. The phrase "very interested in what you have to say" implies a strong desire to learn more about the company, its work, and the interviewee\'s perspective within it.  However, it\'s indirect.  It would be stronger if the interest were linked directly to something specific about the company or role.\n\n**Grade:**\n\nB+  (Good, but could be improved)\n\n\n**Follow-up Question:**\n\n"That\'s excellent.  To help me understand your interest better, could you tell me what specifically about [Company Name/the role/this interview opportunity] has piqued your interest?"\n\n\n**Feedback for Improvement:**\n\nWhile politeness is key, the response lacks specificity.  To make it even stronger, the user should mention something specific that generated their interest. For example:\n\n* "Hello sir, I\'m very interested in what you have to say, particularly regarding [Company Name]\'s recent work on [Specific Project or Initiative]."\n* "Hello sir, I\'m very interested in hearing your perspective on [Aspect of the role/company culture] as described in the job description."\n\nBy adding a specific detail, the candidate demonstrates more focused interest and shows they\'ve done their research.  This makes a stronger impression.\n'
# gradeResult.text='95\n'
# Interview results saved as interview_results.json

# %%
# !pip install langchain
# Out:
# Requirement already satisfied: langchain in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (0.3.15)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langchain) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langchain) (3.11.11)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.31 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langchain) (0.3.31)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langchain) (0.3.5)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langchain) (0.3.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langchain) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langchain-core<0.4.0,>=0.3.31->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langchain-core<0.4.0,>=0.3.31->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langchain-core<0.4.0,>=0.3.31->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from requests<3,>=2->langchain) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.8.0)
# Requirement already satisfied: httpcore==1.* in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: sniffio in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.31->langchain) (3.0.0)
# [notice] A new release of pip available: 22.3 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install -U generative-ai-hub-sdk[langchain]
# Out:
# Collecting generative-ai-hub-sdk[langchain]
#   Downloading generative_ai_hub_sdk-4.1.1-py3-none-any.whl (356 kB)
#      -------------------------------------- 356.0/356.0 kB 7.4 MB/s eta 0:00:00
# Collecting click>=8.1.7
#   Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Collecting pydantic==2.9.2
#   Downloading pydantic-2.9.2-py3-none-any.whl (434 kB)
#      ------------------------------------- 434.9/434.9 kB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: openai>=1.56.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from generative-ai-hub-sdk[langchain]) (1.60.1)
# Collecting overloading==0.5.0
#   Downloading overloading-0.5.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: packaging>=23.2 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from generative-ai-hub-sdk[langchain]) (24.2)
# Collecting dacite>=1.8.1
#   Downloading dacite-1.8.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: requests>=2.32.3 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from generative-ai-hub-sdk[langchain]) (2.32.3)
# Collecting ai-core-sdk>=2.4.14
#   Downloading ai_core_sdk-2.4.14-py3-none-any.whl (152 kB)
#      -------------------------------------- 152.6/152.6 kB 8.9 MB/s eta 0:00:00
# Collecting langchain-community~=0.3.0
#   Downloading langchain_community-0.3.15-py3-none-any.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 10.0 MB/s eta 0:00:00
# Collecting langchain-aws==0.2.1
#   Downloading langchain_aws-0.2.1-py3-none-any.whl (83 kB)
#      ---------------------------------------- 83.9/83.9 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: langchain~=0.3.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from generative-ai-hub-sdk[langchain]) (0.3.15)
# Collecting langchain-google-vertexai==2.0.1
#   Downloading langchain_google_vertexai-2.0.1-py3-none-any.whl (86 kB)
#      ---------------------------------------- 86.9/86.9 kB ? eta 0:00:00
# Collecting langchain-openai==0.2.9
#   Downloading langchain_openai-0.2.9-py3-none-any.whl (50 kB)
#      ---------------------------------------- 50.4/50.4 kB ? eta 0:00:00
# Collecting boto3>=1.34.131
#   Downloading boto3-1.36.6-py3-none-any.whl (139 kB)
#      -------------------------------------- 139.2/139.2 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: langchain-core<0.4,>=0.3.2 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langchain-aws==0.2.1->generative-ai-hub-sdk[langchain]) (0.3.31)
# Requirement already satisfied: numpy<2,>=1 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langchain-aws==0.2.1->generative-ai-hub-sdk[langchain]) (1.26.4)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.56.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langchain-google-vertexai==2.0.1->generative-ai-hub-sdk[langchain]) (1.71.1)
# Requirement already satisfied: google-cloud-storage<3.0.0,>=2.17.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langchain-google-vertexai==2.0.1->generative-ai-hub-sdk[langchain]) (2.19.0)
# Collecting httpx<0.28.0,>=0.27.0
#   Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#      ---------------------------------------- 76.4/76.4 kB 2.1 MB/s eta 0:00:00
# Collecting httpx-sse<0.5.0,>=0.4.0
#   Using cached httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Collecting tiktoken<1,>=0.7
#   Using cached tiktoken-0.8.0-cp311-cp311-win_amd64.whl (884 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from pydantic==2.9.2->generative-ai-hub-sdk[langchain]) (0.7.0)
# Collecting pydantic-core==2.23.4
#   Downloading pydantic_core-2.23.4-cp311-none-win_amd64.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from pydantic==2.9.2->generative-ai-hub-sdk[langchain]) (4.12.2)
# Collecting ai-api-client-sdk==2.4.0
#   Downloading ai_api_client_sdk-2.4.0-py3-none-any.whl (264 kB)
#      -------------------------------------- 264.0/264.0 kB 8.2 MB/s eta 0:00:00
# Collecting aenum~=3.1
#   Downloading aenum-3.1.15-py3-none-any.whl (137 kB)
#      -------------------------------------- 137.6/137.6 kB 8.5 MB/s eta 0:00:00
# Collecting pyhumps~=3.0
#   Downloading pyhumps-3.8.0-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: colorama in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from click>=8.1.7->generative-ai-hub-sdk[langchain]) (0.4.6)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langchain~=0.3.0->generative-ai-hub-sdk[langchain]) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langchain~=0.3.0->generative-ai-hub-sdk[langchain]) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langchain~=0.3.0->generative-ai-hub-sdk[langchain]) (3.11.11)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langchain~=0.3.0->generative-ai-hub-sdk[langchain]) (0.3.5)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langchain~=0.3.0->generative-ai-hub-sdk[langchain]) (0.3.1)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langchain~=0.3.0->generative-ai-hub-sdk[langchain]) (9.0.0)
# Collecting dataclasses-json<0.7,>=0.5.7
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0
#   Using cached pydantic_settings-2.7.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from openai>=1.56.0->generative-ai-hub-sdk[langchain]) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from openai>=1.56.0->generative-ai-hub-sdk[langchain]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from openai>=1.56.0->generative-ai-hub-sdk[langchain]) (0.8.2)
# Requirement already satisfied: sniffio in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from openai>=1.56.0->generative-ai-hub-sdk[langchain]) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from openai>=1.56.0->generative-ai-hub-sdk[langchain]) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from requests>=2.32.3->generative-ai-hub-sdk[langchain]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from requests>=2.32.3->generative-ai-hub-sdk[langchain]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from requests>=2.32.3->generative-ai-hub-sdk[langchain]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from requests>=2.32.3->generative-ai-hub-sdk[langchain]) (2024.12.14)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain~=0.3.0->generative-ai-hub-sdk[langchain]) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain~=0.3.0->generative-ai-hub-sdk[langchain]) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain~=0.3.0->generative-ai-hub-sdk[langchain]) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain~=0.3.0->generative-ai-hub-sdk[langchain]) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain~=0.3.0->generative-ai-hub-sdk[langchain]) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain~=0.3.0->generative-ai-hub-sdk[langchain]) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain~=0.3.0->generative-ai-hub-sdk[langchain]) (1.18.3)
# Collecting botocore<1.37.0,>=1.36.6
#   Downloading botocore-1.36.6-py3-none-any.whl (13.3 MB)
#      ---------------------------------------- 13.3/13.3 MB 9.9 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1
#   Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.12.0,>=0.11.0
#   Downloading s3transfer-0.11.2-py3-none-any.whl (84 kB)
#      ---------------------------------------- 84.2/84.2 kB ? eta 0:00:00
# Collecting marshmallow<4.0.0,>=3.18.0
#   Downloading marshmallow-3.26.0-py3-none-any.whl (50 kB)
#      ---------------------------------------- 50.8/50.8 kB ? eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0
#   Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.56.0->langchain-google-vertexai==2.0.1->generative-ai-hub-sdk[langchain]) (2.24.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.56.0->langchain-google-vertexai==2.0.1->generative-ai-hub-sdk[langchain]) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.56.0->langchain-google-vertexai==2.0.1->generative-ai-hub-sdk[langchain]) (1.25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.56.0->langchain-google-vertexai==2.0.1->generative-ai-hub-sdk[langchain]) (5.29.3)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.56.0->langchain-google-vertexai==2.0.1->generative-ai-hub-sdk[langchain]) (3.29.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.56.0->langchain-google-vertexai==2.0.1->generative-ai-hub-sdk[langchain]) (1.14.0)
# Requirement already satisfied: shapely<3.0.0dev in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.56.0->langchain-google-vertexai==2.0.1->generative-ai-hub-sdk[langchain]) (2.0.6)
# Requirement already satisfied: docstring-parser<1 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.56.0->langchain-google-vertexai==2.0.1->generative-ai-hub-sdk[langchain]) (0.16)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from google-cloud-storage<3.0.0,>=2.17.0->langchain-google-vertexai==2.0.1->generative-ai-hub-sdk[langchain]) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.7.2 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from google-cloud-storage<3.0.0,>=2.17.0->langchain-google-vertexai==2.0.1->generative-ai-hub-sdk[langchain]) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from google-cloud-storage<3.0.0,>=2.17.0->langchain-google-vertexai==2.0.1->generative-ai-hub-sdk[langchain]) (1.6.0)
# Requirement already satisfied: httpcore==1.* in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from httpx<0.28.0,>=0.27.0->langchain-google-vertexai==2.0.1->generative-ai-hub-sdk[langchain]) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->langchain-google-vertexai==2.0.1->generative-ai-hub-sdk[langchain]) (0.14.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langchain-core<0.4,>=0.3.2->langchain-aws==0.2.1->generative-ai-hub-sdk[langchain]) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain~=0.3.0->generative-ai-hub-sdk[langchain]) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain~=0.3.0->generative-ai-hub-sdk[langchain]) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain~=0.3.0->generative-ai-hub-sdk[langchain]) (0.23.0)
# Collecting python-dotenv>=0.21.0
#   Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain~=0.3.0->generative-ai-hub-sdk[langchain]) (3.1.1)
# Collecting regex>=2022.1.18
#   Using cached regex-2024.11.6-cp311-cp311-win_amd64.whl (274 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from botocore<1.37.0,>=1.36.6->boto3>=1.34.131->langchain-aws==0.2.1->generative-ai-hub-sdk[langchain]) (2.9.0.post0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.56.0->langchain-google-vertexai==2.0.1->generative-ai-hub-sdk[langchain]) (1.66.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.56.0->langchain-google-vertexai==2.0.1->generative-ai-hub-sdk[langchain]) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.56.0->langchain-google-vertexai==2.0.1->generative-ai-hub-sdk[langchain]) (1.70.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.56.0->langchain-google-vertexai==2.0.1->generative-ai-hub-sdk[langchain]) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.56.0->langchain-google-vertexai==2.0.1->generative-ai-hub-sdk[langchain]) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.56.0->langchain-google-vertexai==2.0.1->generative-ai-hub-sdk[langchain]) (4.9)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.56.0->langchain-google-vertexai==2.0.1->generative-ai-hub-sdk[langchain]) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3.2->langchain-aws==0.2.1->generative-ai-hub-sdk[langchain]) (3.0.0)
# Collecting mypy-extensions>=0.3.0
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.56.0->langchain-google-vertexai==2.0.1->generative-ai-hub-sdk[langchain]) (0.6.1)
# Requirement already satisfied: six>=1.5 in c:\users\ashee_mpie0zd\geese\newgeese\env_name\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.37.0,>=1.36.6->boto3>=1.34.131->langchain-aws==0.2.1->generative-ai-hub-sdk[langchain]) (1.17.0)
# Installing collected packages: pyhumps, overloading, aenum, regex, python-dotenv, pydantic-core, mypy-extensions, marshmallow, jmespath, httpx-sse, dacite, click, typing-inspect, tiktoken, pydantic, httpx, botocore, ai-api-client-sdk, s3transfer, pydantic-settings, dataclasses-json, ai-core-sdk, generative-ai-hub-sdk, boto3, langchain-openai, langchain-aws, langchain-google-vertexai, langchain-community
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.27.2
#     Uninstalling pydantic_core-2.27.2:
#       Successfully uninstalled pydantic_core-2.27.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.10.6
#     Uninstalling pydantic-2.10.6:
#       Successfully uninstalled pydantic-2.10.6
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
# Successfully installed aenum-3.1.15 ai-api-client-sdk-2.4.0 ai-core-sdk-2.4.14 boto3-1.36.6 botocore-1.36.6 click-8.1.8 dacite-1.8.1 dataclasses-json-0.6.7 generative-ai-hub-sdk-4.1.1 httpx-0.27.2 httpx-sse-0.4.0 jmespath-1.0.1 langchain-aws-0.2.1 langchain-community-0.3.15 langchain-google-vertexai-2.0.1 langchain-openai-0.2.9 marshmallow-3.26.0 mypy-extensions-1.0.0 overloading-0.5.0 pydantic-2.9.2 pydantic-core-2.23.4 pydantic-settings-2.7.1 pyhumps-3.8.0 python-dotenv-1.0.1 regex-2024.11.6 s3transfer-0.11.2 tiktoken-0.8.0 typing-inspect-0.9.0
# [notice] A new release of pip available: 22.3 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import langchain

os.environ["GOOGLE_API_KEY"] = "AIzaSyCZVHNl_bOBOHrrEyQuWut89fvuc15P0HQ"

from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-pro",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    # other params...
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 6
#       2 import langchain
#       4 os.environ["GOOGLE_API_KEY"] = "AIzaSyCZVHNl_bOBOHrrEyQuWut89fvuc15P0HQ"
# ----> 6 from langchain_google_genai import ChatGoogleGenerativeAI
#       8 llm = ChatGoogleGenerativeAI(
#       9     model="gemini-1.5-pro",
#      10     temperature=0,
#    (...)
#      14     # other params...
#      15 )
#
# ModuleNotFoundError: No module named 'langchain_google_genai'
